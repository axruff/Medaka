# %%
from pathlib import Path
from xml.dom import minidom
import numpy as np
import pandas as pd

import os
import filecmp

from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7320\509103518.py in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from math import round
#       6
#       7 import os
#
# ImportError: cannot import name 'round' from 'math' (unknown location)

# %%
path = Path("c:\\Users\\fe0968\\Documents\\data\\medaka\\landmarks\\workshop_landmarks_selected\\")

# %%
path_alex = path / 'pointsets_alexey'
path_TT = path / 'Pointsets_803_4_TT'
path_JB = path / 'Pointsets_JB'
path_JB2 = path / 'Pointsets_JB2'

# %%
set_vert = {
    'name': 'Vert',
    'file_name': 'PointSet1_Vert'.lower(),
    'landmarks': [
        'Transition skull to spine',
        'Vert1',
        'Vert2',
        'Vert3',
        'Vert4',
        'Vert5',
        'Vert_Last_Center'
    ]
}

set_fins = {
    'name': 'Fins',
    'file_name': 'PointSet2_Fins'.lower(),
    'landmarks': [
        'Pectoral_dorsal most breast fin to body connection 1_right',
        'Pectoral_dorsal most breast fin to body connection 2_left',
        'Abdominal_fins back 1_right',
        'Abdominal_fins back 2_left'
    ]
}

set_digest = {
    'name': 'Digest',
    'file_name': 'PointSet3_Digest'.lower(),
    'landmarks': [
        'anus_Center',
        'esophagus'
    ]
}

set_heart = {
    'name': 'Heart',
    'file_name': 'PointSet4_Heart'.lower(),
    'landmarks': [
        'tip of bulbus arteriosus vessel inside',
        'sinus venosus',
        'apex of ventricle',
        'anterior most point of ventricle'
    ]
}

set_eyes = {
    'name': 'Eyes',
    'file_name': 'PointSet5_Eyes'.lower(),
    'landmarks': [
        'optic nerve head 1_right',
        'optic nerve head 2_left',
        'optic chiasm_crossing',
        'most_anterior_right',
        'most_anterior_lef',
        'most_posterior_right',
        'most_posterior_left',
        'most_dorsal_right',
        'most_dorsal_left',
        'most_ventral_right',
        'most_ventral_left'
    ]
}

set_skull_front = {
    'name': 'Skull Front',
    'file_name': 'PointSet6_Skull_Front'.lower(),
    'landmarks': [
        'ventral side of nostril outlet right',
        'ventral side of nostril outlet left',
        'dorsal side of nostril outlet right',
        'dorsal side of nostril outlet left',
        'mandible dentary',
        'tongue tip',
        'upper jaw channel',
        'hyoid fusion'
    ]
}

set_skull_center = {
    'name': 'Skull Center',
    'file_name': 'PointSet7_Skull_Center'.lower(),
    'landmarks': [
        'subhypophysis bone',
        'hyoid between branchial arches',
        'split of afferent branchial artery 1',
        'split of afferent branchial artery 2',
        'split of afferent branchial artery 3',
        'gills bone right',
        'gills bone left'
    ]
}

set_skull_end = {
    'name': 'Skull End',
    'file_name': 'PointSet8_Skull_End'.lower(),
    'landmarks': [
        'skull landmark A right',
        'skull landmark A left',
        'transition skull to spine',
        'fusion of epibranchial artery 2',
        'center of utricle right',
        'center of utricle left'
    ]
}

set_brain = {
    'name': 'Brain',
    'file_name': 'PointSet9_Brain'.lower(),
    'landmarks': [
    'hypophysis',
    'olfactoryN_right',
    'olfactoryN_left',
    'glomerulosus_R',
    'glomerulosus_L',
    'OT_rightmost',
    'OT_leftmost',
    'cerebellum',
    'OT cerebellum torus',
    'epiphysis'
    ]
}

all_landmarks = [set_vert, set_fins, set_digest, set_heart, set_eyes, set_skull_front, set_skull_center, set_skull_end, set_brain]

landmarks_pointset_names = [x['file_name'] for x in all_landmarks]

print(landmarks_pointset_names)
# Out:
# ['pointset1_vert', 'pointset2_fins', 'pointset3_digest', 'pointset4_heart', 'pointset5_eyes', 'pointset6_skull_front', 'pointset7_skull_center', 'pointset8_skull_end', 'pointset9_brain']

# %%
def read_landmarks(file_name, mode='def'):
    
    if mode == 'lowercase':
        file_name = file_name.lower()
    
    with open(str(file_name), 'r') as f:
        data = f.read()
    
    xml_data = BeautifulSoup(data, "xml")
    points = xml_data.find_all('point')
    
    landmarks = []

    for p in points:
        if p.find('x').text == '0' and p.find('y').text == '0' and p.find('z').text == '0':
            continue

        x = float(p.find('x').text)
        y = float(p.find('y').text)
        z = float(p.find('z').text)

        landmarks.append(np.asarray([x,y,z]))
        
    f.close()
        
    return landmarks

def get_distance(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def print_landmark_comparison(landmark_set, landmark1, landmark2, landmark3, landmark4):
     
    #print('------------------------------------------------------------------------')
    print(landmark_set['name'])
    #print('------------------------------------------------------------------------')
    data = {'landmark': landmark_set['landmarks'],
           'AE vs TT': [get_distance(landmark1[i], landmark2[i]) for i in range(len(landmark_set['landmarks']))],
            'AE vs JB': [get_distance(landmark1[i], landmark3[i]) for i in range(len(landmark_set['landmarks']))],
            'TT vs JB': [get_distance(landmark2[i], landmark3[i]) for i in range(len(landmark_set['landmarks']))],
            'JB vs JB2': [get_distance(landmark3[i], landmark4[i]) for i in range(len(landmark_set['landmarks']))]
           }
    
    df = pd.DataFrame(data)
    return df

    ##print(df)
    ##print()
    ##print(df.describe())
    
def read_landmarks_all_three(landmark_set):
    land_ae = read_landmarks(path_alex / landmark_set['file_name'])
    land_tt = read_landmarks(path_TT / landmark_set['file_name'])
    land_jb = read_landmarks(path_JB / landmark_set['file_name'])
    land_jb2 = read_landmarks(path_JB2 / landmark_set['file_name'])

    return land_ae, land_tt, land_jb, land_jb2

def show_results(i):
    land_ae, land_tt, land_jb, land_jb2 = read_landmarks_all_three(all_landmarks[i])
    df = print_landmark_comparison(all_landmarks[i], land_ae, land_tt, land_jb, land_jb2)
    return df.round(1).style.pipe(make_pretty)
    return df.round(1).style.pipe(make_pretty)

def make_pretty(styler):
    #styler.set_caption("Weather Conditions")
    #styler.format(rain_condition)
    #styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=0, vmax=20, cmap="coolwarm")
    #styler.background_gradient(axis=None, cmap="coolwarm")
    return styler
    

def fix_files(file_list, old_name, new_name):
    
    if old_name in file_list:
        file_list[file_list.index(old_name)] = new_name
        if os.path.exists(data_path / old_name):
            os.rename(data_path / old_name, data_path / new_name)
    return file_list
    
def print_landmarks_count_for_pointsets():
    for land in all_landmarks:
        print(f"{land['file_name']}: {len(land['landmarks'])} landmarks")

# %%
print_landmarks_count_for_pointsets()
# Out:
# pointset1_vert: 7 landmarks
# pointset2_fins: 4 landmarks
# pointset3_digest: 2 landmarks
# pointset4_heart: 4 landmarks
# pointset5_eyes: 11 landmarks
# pointset6_skull_front: 8 landmarks
# pointset7_skull_center: 7 landmarks
# pointset8_skull_end: 6 landmarks
# pointset9_brain: 10 landmarks

# %% [markdown]
# ## Landmark Consistancy

# %%
show_results(0)

# %%
show_results(1)
# Out:
# Fins
# <style type="text/css">
# #T_9de7e_row0_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_9de7e_row0_col2, #T_9de7e_row0_col3, #T_9de7e_row1_col2, #T_9de7e_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9de7e_row0_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_9de7e_row1_col1, #T_9de7e_row2_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_9de7e_row1_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9de7e_row2_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_9de7e_row2_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_9de7e_row2_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9de7e_row3_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_9de7e_row3_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_9de7e_row3_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_9de7e_row3_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# </style>
# <table id="T_9de7e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9de7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9de7e_row0_col0" class="data row0 col0" >Pectoral_dorsal most breast fin to body connection 1_right</td>
#       <td id="T_9de7e_row0_col1" class="data row0 col1" >8.800000</td>
#       <td id="T_9de7e_row0_col2" class="data row0 col2" >139.700000</td>
#       <td id="T_9de7e_row0_col3" class="data row0 col3" >136.900000</td>
#       <td id="T_9de7e_row0_col4" class="data row0 col4" >2.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9de7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9de7e_row1_col0" class="data row1 col0" >Pectoral_dorsal most breast fin to body connection 2_left</td>
#       <td id="T_9de7e_row1_col1" class="data row1 col1" >12.100000</td>
#       <td id="T_9de7e_row1_col2" class="data row1 col2" >140.900000</td>
#       <td id="T_9de7e_row1_col3" class="data row1 col3" >140.400000</td>
#       <td id="T_9de7e_row1_col4" class="data row1 col4" >2.100000</td>
#     </tr>
#     <tr>
#       <th id="T_9de7e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9de7e_row2_col0" class="data row2 col0" >Abdominal_fins back 1_right</td>
#       <td id="T_9de7e_row2_col1" class="data row2 col1" >15.600000</td>
#       <td id="T_9de7e_row2_col2" class="data row2 col2" >12.100000</td>
#       <td id="T_9de7e_row2_col3" class="data row2 col3" >6.500000</td>
#       <td id="T_9de7e_row2_col4" class="data row2 col4" >5.400000</td>
#     </tr>
#     <tr>
#       <th id="T_9de7e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9de7e_row3_col0" class="data row3 col0" >Abdominal_fins back 2_left</td>
#       <td id="T_9de7e_row3_col1" class="data row3 col1" >7.500000</td>
#       <td id="T_9de7e_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_9de7e_row3_col3" class="data row3 col3" >5.800000</td>
#       <td id="T_9de7e_row3_col4" class="data row3 col4" >11.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_results(2)
# Out:
# Digest
# <style type="text/css">
# #T_a221e_row0_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a221e_row0_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_a221e_row0_col3 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a221e_row0_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a221e_row1_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a221e_row1_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a221e_row1_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a221e_row1_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a221e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a221e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a221e_row0_col0" class="data row0 col0" >anus_Center</td>
#       <td id="T_a221e_row0_col1" class="data row0 col1" >0.800000</td>
#       <td id="T_a221e_row0_col2" class="data row0 col2" >15.500000</td>
#       <td id="T_a221e_row0_col3" class="data row0 col3" >14.900000</td>
#       <td id="T_a221e_row0_col4" class="data row0 col4" >1.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a221e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a221e_row1_col0" class="data row1 col0" >esophagus</td>
#       <td id="T_a221e_row1_col1" class="data row1 col1" >4.900000</td>
#       <td id="T_a221e_row1_col2" class="data row1 col2" >1.400000</td>
#       <td id="T_a221e_row1_col3" class="data row1 col3" >5.300000</td>
#       <td id="T_a221e_row1_col4" class="data row1 col4" >3.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_results(3)
# Out:
# Heart
# <style type="text/css">
# #T_5e9c6_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_5e9c6_row0_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5e9c6_row0_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5e9c6_row0_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5e9c6_row1_col1, #T_5e9c6_row1_col3, #T_5e9c6_row1_col4, #T_5e9c6_row2_col2, #T_5e9c6_row2_col3, #T_5e9c6_row2_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5e9c6_row1_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_5e9c6_row2_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5e9c6_row3_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5e9c6_row3_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5e9c6_row3_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5e9c6_row3_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5e9c6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e9c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e9c6_row0_col0" class="data row0 col0" >tip of bulbus arteriosus vessel inside</td>
#       <td id="T_5e9c6_row0_col1" class="data row0 col1" >10.800000</td>
#       <td id="T_5e9c6_row0_col2" class="data row0 col2" >1.100000</td>
#       <td id="T_5e9c6_row0_col3" class="data row0 col3" >10.900000</td>
#       <td id="T_5e9c6_row0_col4" class="data row0 col4" >1.800000</td>
#     </tr>
#     <tr>
#       <th id="T_5e9c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e9c6_row1_col0" class="data row1 col0" >sinus venosus</td>
#       <td id="T_5e9c6_row1_col1" class="data row1 col1" >54.700000</td>
#       <td id="T_5e9c6_row1_col2" class="data row1 col2" >11.300000</td>
#       <td id="T_5e9c6_row1_col3" class="data row1 col3" >45.700000</td>
#       <td id="T_5e9c6_row1_col4" class="data row1 col4" >40.300000</td>
#     </tr>
#     <tr>
#       <th id="T_5e9c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e9c6_row2_col0" class="data row2 col0" >apex of ventricle</td>
#       <td id="T_5e9c6_row2_col1" class="data row2 col1" >7.000000</td>
#       <td id="T_5e9c6_row2_col2" class="data row2 col2" >30.200000</td>
#       <td id="T_5e9c6_row2_col3" class="data row2 col3" >37.000000</td>
#       <td id="T_5e9c6_row2_col4" class="data row2 col4" >37.800000</td>
#     </tr>
#     <tr>
#       <th id="T_5e9c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e9c6_row3_col0" class="data row3 col0" >anterior most point of ventricle</td>
#       <td id="T_5e9c6_row3_col1" class="data row3 col1" >1.300000</td>
#       <td id="T_5e9c6_row3_col2" class="data row3 col2" >3.200000</td>
#       <td id="T_5e9c6_row3_col3" class="data row3 col3" >3.700000</td>
#       <td id="T_5e9c6_row3_col4" class="data row3 col4" >0.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_results(4)
# Out:
# Eyes
# <style type="text/css">
# #T_265c4_row0_col1, #T_265c4_row9_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_265c4_row0_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_265c4_row0_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_265c4_row0_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_265c4_row1_col1, #T_265c4_row2_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_265c4_row1_col2, #T_265c4_row4_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_265c4_row1_col3, #T_265c4_row3_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_265c4_row1_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_265c4_row2_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_265c4_row2_col3, #T_265c4_row9_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_265c4_row2_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_265c4_row3_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_265c4_row3_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_265c4_row3_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_265c4_row4_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_265c4_row4_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_265c4_row4_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_265c4_row5_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_265c4_row5_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_265c4_row5_col3, #T_265c4_row10_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_265c4_row5_col4, #T_265c4_row7_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_265c4_row6_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_265c4_row6_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_265c4_row6_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_265c4_row6_col4, #T_265c4_row7_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_265c4_row7_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_265c4_row7_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_265c4_row8_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_265c4_row8_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_265c4_row8_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_265c4_row8_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_265c4_row9_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_265c4_row9_col4, #T_265c4_row10_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_265c4_row10_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_265c4_row10_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# </style>
# <table id="T_265c4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_265c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_265c4_row0_col0" class="data row0 col0" >optic nerve head 1_right</td>
#       <td id="T_265c4_row0_col1" class="data row0 col1" >4.100000</td>
#       <td id="T_265c4_row0_col2" class="data row0 col2" >1.400000</td>
#       <td id="T_265c4_row0_col3" class="data row0 col3" >5.500000</td>
#       <td id="T_265c4_row0_col4" class="data row0 col4" >7.200000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_265c4_row1_col0" class="data row1 col0" >optic nerve head 2_left</td>
#       <td id="T_265c4_row1_col1" class="data row1 col1" >2.000000</td>
#       <td id="T_265c4_row1_col2" class="data row1 col2" >6.300000</td>
#       <td id="T_265c4_row1_col3" class="data row1 col3" >8.100000</td>
#       <td id="T_265c4_row1_col4" class="data row1 col4" >8.200000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_265c4_row2_col0" class="data row2 col0" >optic chiasm_crossing</td>
#       <td id="T_265c4_row2_col1" class="data row2 col1" >6.200000</td>
#       <td id="T_265c4_row2_col2" class="data row2 col2" >2.000000</td>
#       <td id="T_265c4_row2_col3" class="data row2 col3" >7.100000</td>
#       <td id="T_265c4_row2_col4" class="data row2 col4" >2.200000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_265c4_row3_col0" class="data row3 col0" >most_anterior_right</td>
#       <td id="T_265c4_row3_col1" class="data row3 col1" >7.600000</td>
#       <td id="T_265c4_row3_col2" class="data row3 col2" >5.700000</td>
#       <td id="T_265c4_row3_col3" class="data row3 col3" >1.900000</td>
#       <td id="T_265c4_row3_col4" class="data row3 col4" >8.100000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_265c4_row4_col0" class="data row4 col0" >most_anterior_lef</td>
#       <td id="T_265c4_row4_col1" class="data row4 col1" >3.300000</td>
#       <td id="T_265c4_row4_col2" class="data row4 col2" >6.300000</td>
#       <td id="T_265c4_row4_col3" class="data row4 col3" >7.000000</td>
#       <td id="T_265c4_row4_col4" class="data row4 col4" >7.800000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_265c4_row5_col0" class="data row5 col0" >most_posterior_right</td>
#       <td id="T_265c4_row5_col1" class="data row5 col1" >5.600000</td>
#       <td id="T_265c4_row5_col2" class="data row5 col2" >1.100000</td>
#       <td id="T_265c4_row5_col3" class="data row5 col3" >4.600000</td>
#       <td id="T_265c4_row5_col4" class="data row5 col4" >1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_265c4_row6_col0" class="data row6 col0" >most_posterior_left</td>
#       <td id="T_265c4_row6_col1" class="data row6 col1" >6.500000</td>
#       <td id="T_265c4_row6_col2" class="data row6 col2" >3.200000</td>
#       <td id="T_265c4_row6_col3" class="data row6 col3" >3.800000</td>
#       <td id="T_265c4_row6_col4" class="data row6 col4" >2.900000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_265c4_row7_col0" class="data row7 col0" >most_dorsal_right</td>
#       <td id="T_265c4_row7_col1" class="data row7 col1" >2.900000</td>
#       <td id="T_265c4_row7_col2" class="data row7 col2" >6.400000</td>
#       <td id="T_265c4_row7_col3" class="data row7 col3" >6.800000</td>
#       <td id="T_265c4_row7_col4" class="data row7 col4" >1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_265c4_row8_col0" class="data row8 col0" >most_dorsal_left</td>
#       <td id="T_265c4_row8_col1" class="data row8 col1" >1.700000</td>
#       <td id="T_265c4_row8_col2" class="data row8 col2" >7.300000</td>
#       <td id="T_265c4_row8_col3" class="data row8 col3" >6.700000</td>
#       <td id="T_265c4_row8_col4" class="data row8 col4" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_265c4_row9_col0" class="data row9 col0" >most_ventral_right</td>
#       <td id="T_265c4_row9_col1" class="data row9 col1" >8.500000</td>
#       <td id="T_265c4_row9_col2" class="data row9 col2" >4.100000</td>
#       <td id="T_265c4_row9_col3" class="data row9 col3" >7.100000</td>
#       <td id="T_265c4_row9_col4" class="data row9 col4" >8.700000</td>
#     </tr>
#     <tr>
#       <th id="T_265c4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_265c4_row10_col0" class="data row10 col0" >most_ventral_left</td>
#       <td id="T_265c4_row10_col1" class="data row10 col1" >8.700000</td>
#       <td id="T_265c4_row10_col2" class="data row10 col2" >4.600000</td>
#       <td id

# %%
show_results(5)
# Out:
# Skull Front
# <style type="text/css">
# #T_9cf39_row0_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_9cf39_row0_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_9cf39_row0_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_9cf39_row0_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_9cf39_row1_col1, #T_9cf39_row5_col2, #T_9cf39_row5_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9cf39_row1_col2, #T_9cf39_row2_col3, #T_9cf39_row6_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_9cf39_row1_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9cf39_row1_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9cf39_row2_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_9cf39_row2_col2, #T_9cf39_row3_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_9cf39_row2_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9cf39_row3_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_9cf39_row3_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9cf39_row3_col4, #T_9cf39_row7_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_9cf39_row4_col1, #T_9cf39_row5_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9cf39_row4_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_9cf39_row4_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_9cf39_row4_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9cf39_row5_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_9cf39_row6_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_9cf39_row6_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_9cf39_row6_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_9cf39_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_9cf39_row7_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_9cf39_row7_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9cf39_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cf39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cf39_row0_col0" class="data row0 col0" >ventral side of nostril outlet right</td>
#       <td id="T_9cf39_row0_col1" class="data row0 col1" >5.700000</td>
#       <td id="T_9cf39_row0_col2" class="data row0 col2" >3.900000</td>
#       <td id="T_9cf39_row0_col3" class="data row0 col3" >2.400000</td>
#       <td id="T_9cf39_row0_col4" class="data row0 col4" >1.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9cf39_row1_col0" class="data row1 col0" >ventral side of nostril outlet left</td>
#       <td id="T_9cf39_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9cf39_row1_col2" class="data row1 col2" >1.500000</td>
#       <td id="T_9cf39_row1_col3" class="data row1 col3" >1.600000</td>
#       <td id="T_9cf39_row1_col4" class="data row1 col4" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9cf39_row2_col0" class="data row2 col0" >dorsal side of nostril outlet right</td>
#       <td id="T_9cf39_row2_col1" class="data row2 col1" >1.200000</td>
#       <td id="T_9cf39_row2_col2" class="data row2 col2" >2.300000</td>
#       <td id="T_9cf39_row2_col3" class="data row2 col3" >1.500000</td>
#       <td id="T_9cf39_row2_col4" class="data row2 col4" >2.100000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9cf39_row3_col0" class="data row3 col0" >dorsal side of nostril outlet left</td>
#       <td id="T_9cf39_row3_col1" class="data row3 col1" >2.200000</td>
#       <td id="T_9cf39_row3_col2" class="data row3 col2" >1.800000</td>
#       <td id="T_9cf39_row3_col3" class="data row3 col3" >2.300000</td>
#       <td id="T_9cf39_row3_col4" class="data row3 col4" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9cf39_row4_col0" class="data row4 col0" >mandible dentary</td>
#       <td id="T_9cf39_row4_col1" class="data row4 col1" >0.800000</td>
#       <td id="T_9cf39_row4_col2" class="data row4 col2" >11.700000</td>
#       <td id="T_9cf39_row4_col3" class="data row4 col3" >12.100000</td>
#       <td id="T_9cf39_row4_col4" class="data row4 col4" >3.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9cf39_row5_col0" class="data row5 col0" >tongue tip</td>
#       <td id="T_9cf39_row5_col1" class="data row5 col1" >0.800000</td>
#       <td id="T_9cf39_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_9cf39_row5_col3" class="data row5 col3" >0.300000</td>
#       <td id="T_9cf39_row5_col4" class="data row5 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9cf39_row6_col0" class="data row6 col0" >upper jaw channel</td>
#       <td id="T_9cf39_row6_col1" class="data row6 col1" >7.900000</td>
#       <td id="T_9cf39_row6_col2" class="data row6 col2" >6.700000</td>
#       <td id="T_9cf39_row6_col3" class="data row6 col3" >1.500000</td>
#       <td id="T_9cf39_row6_col4" class="data row6 col4" >3.300000</td>
#     </tr>
#     <tr>
#       <th id="T_9cf39_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9cf39_row7_col0" class="data row7 col0" >hyoid fusion</td>
#       <td id="T_9cf39_row7_col1" class="data row7 col1" >4.300000</td>
#       <td id="T_9cf39_row7_col2" class="data row7 col2" >3.600000</td>
#       <td id="T_9cf39_row7_col3" class="data row7 col3" >0.900000</td>
#       <td id="T_9cf39_row7_col4" class="data row7 col4" >3.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_results(6)
# Out:
# Skull Center
# <style type="text/css">
# #T_4e5bc_row0_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_4e5bc_row0_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_4e5bc_row0_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4e5bc_row0_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_4e5bc_row1_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_4e5bc_row1_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_4e5bc_row1_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_4e5bc_row1_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_4e5bc_row2_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_4e5bc_row2_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_4e5bc_row2_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_4e5bc_row2_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_4e5bc_row3_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_4e5bc_row3_col2, #T_4e5bc_row6_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_4e5bc_row3_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_4e5bc_row3_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4e5bc_row4_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4e5bc_row4_col2, #T_4e5bc_row5_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_4e5bc_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_4e5bc_row4_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_4e5bc_row5_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_4e5bc_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4e5bc_row5_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_4e5bc_row6_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4e5bc_row6_col3, #T_4e5bc_row6_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e5bc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e5bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e5bc_row0_col0" class="data row0 col0" >subhypophysis bone</td>
#       <td id="T_4e5bc_row0_col1" class="data row0 col1" >7.100000</td>
#       <td id="T_4e5bc_row0_col2" class="data row0 col2" >8.600000</td>
#       <td id="T_4e5bc_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_4e5bc_row0_col4" class="data row0 col4" >5.200000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e5bc_row1_col0" class="data row1 col0" >hyoid between branchial arches</td>
#       <td id="T_4e5bc_row1_col1" class="data row1 col1" >2.200000</td>
#       <td id="T_4e5bc_row1_col2" class="data row1 col2" >1.700000</td>
#       <td id="T_4e5bc_row1_col3" class="data row1 col3" >0.800000</td>
#       <td id="T_4e5bc_row1_col4" class="data row1 col4" >11.900000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e5bc_row2_col0" class="data row2 col0" >split of afferent branchial artery 1</td>
#       <td id="T_4e5bc_row2_col1" class="data row2 col1" >4.700000</td>
#       <td id="T_4e5bc_row2_col2" class="data row2 col2" >3.600000</td>
#       <td id="T_4e5bc_row2_col3" class="data row2 col3" >7.200000</td>
#       <td id="T_4e5bc_row2_col4" class="data row2 col4" >2.100000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e5bc_row3_col0" class="data row3 col0" >split of afferent branchial artery 2</td>
#       <td id="T_4e5bc_row3_col1" class="data row3 col1" >3.700000</td>
#       <td id="T_4e5bc_row3_col2" class="data row3 col2" >3.300000</td>
#       <td id="T_4e5bc_row3_col3" class="data row3 col3" >6.800000</td>
#       <td id="T_4e5bc_row3_col4" class="data row3 col4" >2.700000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e5bc_row4_col0" class="data row4 col0" >split of afferent branchial artery 3</td>
#       <td id="T_4e5bc_row4_col1" class="data row4 col1" >20.700000</td>
#       <td id="T_4e5bc_row4_col2" class="data row4 col2" >4.000000</td>
#       <td id="T_4e5bc_row4_col3" class="data row4 col3" >19.700000</td>
#       <td id="T_4e5bc_row4_col4" class="data row4 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5bc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e5bc_row5_col0" class="data row5 col0" >gills bone right</td>
#       <td id="T_4e5bc_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_4e5bc_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_4e5bc_row5_col3" class="data row5 col3" >3.800000</td>
#       <td id="T_4e5bc_row5_col4" class="data row5 col4" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5bc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4e5bc_row6_col0" class="data row6 col0" >gills bone left</td>
#       <td id="T_4e5bc_row6_col1" class="data row6 col1" >3.300000</td>
#       <td id="T_4e5bc_row6_col2" class="data row6 col2" >1.300000</td>
#       <td id="T_4e5bc_row6_col3" class="data row6 col3" >4.100000</td>
#       <td id="T_4e5bc_row6_col4" class="data row6 col4" >4.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_results(7)
# Out:
# Skull End
# <style type="text/css">
# #T_9358b_row0_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_9358b_row0_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9358b_row0_col3, #T_9358b_row2_col4, #T_9358b_row3_col1, #T_9358b_row3_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9358b_row0_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_9358b_row1_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_9358b_row1_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9358b_row1_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9358b_row1_col4 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_9358b_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_9358b_row2_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_9358b_row2_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9358b_row3_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_9358b_row3_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_9358b_row4_col1, #T_9358b_row4_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_9358b_row4_col3, #T_9358b_row5_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_9358b_row4_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_9358b_row5_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_9358b_row5_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_9358b_row5_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9358b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >landmark</th>
#       <th class="col_heading level0 col1" >AE vs TT</th>
#       <th class="col_heading level0 col2" >AE vs JB</th>
#       <th class="col_heading level0 col3" >TT vs JB</th>
#       <th class="col_heading level0 col4" >JB vs JB2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9358b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9358b_row0_col0" class="data row0 col0" >skull landmark A right</td>
#       <td id="T_9358b_row0_col1" class="data row0 col1" >1.400000</td>
#       <td id="T_9358b_row0_col2" class="data row0 col2" >2.700000</td>
#       <td id="T_9358b_row0_col3" class="data row0 col3" >3.700000</td>
#       <td id="T_9358b_row0_col4" class="data row0 col4" >14.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9358b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9358b_row1_col0" class="data row1 col0" >skull landmark A left</td>
#       <td id="T_9358b_row1_col1" class="data row1 col1" >2.900000</td>
#       <td id="T_9358b_row1_col2" class="data row1 col2" >2.100000</td>
#       <td id="T_9358b_row1_col3" class="data row1 col3" >1.100000</td>
#       <td id="T_9358b_row1_col4" class="data row1 col4" >17.400000</td>
#     </tr>
#     <tr>
#       <th id="T_9358b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9358b_row2_col0" class="data row2 col0" >transition skull to spine</td>
#       <td id="T_9358b_row2_col1" class="data row2 col1" >2.000000</td>
#       <td id="T_9358b_row2_col2" class="data row2 col2" >3.400000</td>
#       <td id="T_9358b_row2_col3" class="data row2 col3" >4.900000</td>
#       <td id="T_9358b_row2_col4" class="data row2 col4" >3.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9358b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9358b_row3_col0" class="data row3 col0" >fusion of epibranchial artery 2</td>
#       <td id="T_9358b_row3_col1" class="data row3 col1" >3.700000</td>
#       <td id="T_9358b_row3_col2" class="data row3 col2" >11.400000</td>
#       <td id="T_9358b_row3_col3" class="data row3 col3" >9.600000</td>
#       <td id="T_9358b_row3_col4" class="data row3 col4" >3.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9358b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9358b_row4_col0" class="data row4 col0" >center of utricle right</td>
#       <td id="T_9358b_row4_col1" class="data row4 col1" >9.100000</td>
#       <td id="T_9358b_row4_col2" class="data row4 col2" >9.100000</td>
#       <td id="T_9358b_row4_col3" class="data row4 col3" >1.200000</td>
#       <td id="T_9358b_row4_col4" class="data row4 col4" >1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_9358b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9358b_row5_col0" class="data row5 col0" >center of utricle left</td>
#       <td id="T_9358b_row5_col1" class="data row5 col1" >8.500000</td>
#       <td id="T_9358b_row5_col2" class="data row5 col2" >8.300000</td>
#       <td id="T_9358b_row5_col3" class="data row5 col3" >0.500000</td>
#       <td id="T_9358b_row5_col4" class="data row5 col4" >1.200000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Testing

# %%
data_path = Path('c:\\Users\\fe0968\\Documents\\Medaka\\inbredpanel_pointsets_v2\\inbredpanel_pointsets\\')

# %%
files = os.listdir(data_path)
files = [f for f in files if os.path.isfile(data_path / f)]
len(files)
# Out:
# 2120

# %%
# Filtering 1: Delete duplicates. Files with (1) in the name
duplicates = []
same_name_diff_content = []

for f in files:
    if '(1)' in f:
        if filecmp.cmp(data_path / f, data_path / f.replace(' (1)', '')):
            duplicates.append(f)
        else:
            same_name_diff_content.append(f)
            
            
print('Duplicates:', len(duplicates))
        
        
filtered_files = [x for x in files if (x not in duplicates)]
print('New:', len(filtered_files))

print()
print('-----------------------------------------------')
print('WARNING. Same name, different content', same_name_diff_content)
print('-----------------------------------------------')

filtered_files = [x for x in filtered_files if (x not in same_name_diff_content)]
print('New:', len(filtered_files))
# Out:
# Duplicates: 80
# New: 2040
#
# -----------------------------------------------
# WARNING. Same name, different content ['1064_pointset1_vert_JO (1).mps']
# -----------------------------------------------
# New: 2039

# %%
manual_exceptions = ['PointSet3_Digest.mps', 'PointSet4_Heart.mps', 'PointSet9_brain.mps', '1370_pointset2_fins.mps', '961_pointset2_fins.mps', '954_pointset9_brain.mps']
manual_exceptions = [x.lower() for x in manual_exceptions]

filtered_files = [x for x in filtered_files if (x.lower() not in manual_exceptions)]
print('New:', len(filtered_files))
# Out:
# New: 2033

# %%
filtered_files = fix_files(filtered_files, '1265PointSet3_Digest_VC.mps', '1265_PointSet3_Digest_VC.mps')
filtered_files = fix_files(filtered_files, '1274pointset6_skull_front_JO.mps', '1274_pointset6_skull_front_JO.mps')
filtered_files = fix_files(filtered_files, '1300_ointSet3_Digest_VC.mps', '1300_PointSet3_Digest_VC.mps')
filtered_files = fix_files(filtered_files, '1300PointSet4_Heart_VC.mps', '1300_PointSet4_Heart_VC.mps')
filtered_files = fix_files(filtered_files, '1300_PointSet2_Vert_CS.mps', '1300_PointSet1_Vert_CS.mps')
filtered_files = fix_files(filtered_files, '876_PointSet3-Digest_VC.mps', '876_PointSet3_Digest_VC.mps')

# %%
samples = []
points = []
names = []

for f in filtered_files:
    
    s = f.split('_')
    samples.append(s[0])
    names.append(s[-1][:-4].lower())
    #points.append(s[1])
    points.append(f.replace(f'{s[0]}_', '').replace(f'_{s[-1]}', '').lower())
    
data = {'sample': samples,
        'point_set': points,
       'name': names}


print('Unique samples:', len(set(samples)))
print(set(samples))

print()

print('Unique pointsets:', len(set(points)))
print(set(points))

print()

print('Unique names:', len(set(names)))
print(set(names))
# Out:
# Unique samples: 181
# {'1404', '814', '1369', '947', '956', '1362', '803', '880', '818', '1257', '1346', '1297', '846', '509', '475', '805', '1105', '1264', '1366', '1380', '511', '856', '547', '1075', '800', '425', '1104', '1232', '500', '1230', '1227', '535', '946', '471', '1391', '1293', '804', '463', '1081', '807', '1134', '1285', '853', '1219', '454', '528', '1310', '531', '1274', '955', '979', '1337', '1291', '508', '1222', '1273', '1217', '582', '961', '871', '876', '1129', '1321', '891', '909', '1256', '1115', '841', '972', '1265', '1305', '1417', '488', '960', '1393', '1338', '1192', '578', '883', '1376', '417', '816', '978', '819', '1295', '1248', '828', '1284', '1131', '913', '811', '565', '1292', '1341', '906', '971', '489', '470', '824', '1400', '1399', '444', '1100', '954', '526', '838', '1389', '1106', '1191', '1082', '502', '1405', '831', '423', '1184', '1064', '854', '919', '1394', '1383', '1418', '537', '561', '1395', '801', '1119', '1353', '1401', '1296', '879', '893', '843', '870', '951', '1396', '1282', '1370', '418', '1384', '834', '849', '1372', '1076', '459', '1234', '1126', '1269', '493', '446', '1258', '890', '1423', '1406', '914', '1216', '428', '1300', '1385', '820', '555', '1157', '1086', '1414', '448', '912', '844', '501', '1181', '1378', '809', '1320', '1351', '1155', '1226', '586', '1323', '826', '1363', '859', '421', '1071'}
#
# Unique pointsets: 9
# {'pointset7_skull_center', 'pointset8_skull_end', 'pointset5_eyes', 'pointset9_brain', 'pointset1_vert', 'pointset6_skull_front', 'pointset2_fins', 'pointset3_digest', 'pointset4_heart'}
#
# Unique names: 13
# {'jvm', 'bew', 'tt', 'vc', 'ca', 'jo', 'kp', 'cs', 'ttt', 'jf', 'ra', 'tc', 'kk'}

# %%
print(landmarks_pointset_names)

print()
print('-----------------------------------------------')
print('WARNING: Problematic naming')
print('-----------------------------------------------')
print([p for p in points if p not in landmarks_pointset_names])

print('Based on pointset names')
print([samples[points.index(p)] + '_' + points[points.index(p)] + '_' + names[points.index(p)]   for p in points if p not in landmarks_pointset_names])


print('Based on names')
print([samples[names.index(p)] + '_' + points[names.index(p)] + '_' + names[names.index(p)]   for p in names if p not in participants])
    
# TODO: Make a list of exact file names to check manually
# Out:
# ['pointset1_vert', 'pointset2_fins', 'pointset3_digest', 'pointset4_heart', 'pointset5_eyes', 'pointset6_skull_front', 'pointset7_skull_center', 'pointset8_skull_end', 'pointset9_brain']
#
# -----------------------------------------------
# WARNING: Problematic naming
# -----------------------------------------------
# []
# Based on pointset names
# []
# Based on names
# []

# %%
people = set(names)
print(people)

print('-----------------------------------------------')
print('WARNING: Problematic names')
print('-----------------------------------------------')
for p in people:
    if p not in participants:
        print('Problematic name: ', p)
        print('Count:', names.count(p))
        print([samples[i] + '_' + points[i] + '_' + names[i] + '.mps' for i, x in enumerate(names) if x == p])
# Out:
# {'jvm', 'bew', 'tt', 'vc', 'ca', 'jo', 'kp', 'cs', 'ttt', 'jf', 'ra', 'tc', 'kk'}
# -----------------------------------------------
# WARNING: Problematic names
# -----------------------------------------------

# %%
[i for i, x in enumerate(names) if x == 'fins']
# Out:
# [799, 1740]

# %% [markdown]
# ## Make a data frame

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ## Participants stats

# %%
participants = ['ca', 'jf', 'tc', 'cs', 'ra', 'kk', 'vc', 'bew', 'ttt', 'kp', 'jo', 'jvm', 'tt']

participants_names = {'jf': 'Jana',
                     'jo': 'Jasmin',
                     'bew': 'Bettina',
                     'ca': 'Cassian',
                     'cs': 'Christina',
                     'jvm': 'Javier',
                     'kk': 'Kristaps',
                     'kp':'Kaisa',
                     'ra':'Rashi',
                     'tc':'???',
                     'tt': 'Thomas',
                     'ttt': 'Tina',
                     'vc': 'Valerie'}

participants_pointset_count= {
                     'jf': 3,
                     'jo': 5,
                     'bew': 4,
                     'ca': 4,
                     'cs': 3,
                     'jvm': 3,
                     'kk': 3,
                     'kp': 5,
                     'ra': 4,
                     'tc': 2,
                     'tt': 3,
                     'ttt': 3,
                     'vc': 5}

print('Participants')
res = df.groupby(['name']).count()
res
# Out:
# Participants
#       sample  point_set
# name
# bew      120        120
# ca       160        160
# cs       177        177
# jf       120        120
# jo       299        299
# jvm      180        180
# kk       180        180
# kp       108        108
# ra       160        160
# tc       120        120
# tt       129        129
# ttt      120        120
# vc       160        160

# %%
print('Current status')
for name in res.index:
    print(f"{participants_names[name]} ({name}): {round(res.loc[name]['point_set'] / (participants_pointset_count[name]*60) * 100 ,1)}% done")
    #print(res.loc[name]['point_set'])
# Out:
# Current status
# Bettina (bew): 50.0% done
# Cassian (ca): 66.7% done
# Christina (cs): 98.3% done
# Jana (jf): 66.7% done
# Jasmin (jo): 99.7% done
# Javier (jvm): 100.0% done
# Kristaps (kk): 100.0% done
# Kaisa (kp): 36.0% done
# Rashi (ra): 66.7% done
# ??? (tc): 100.0% done
# Thomas (tt): 71.7% done
# Tina (ttt): 66.7% done
# Valerie (vc): 53.3% done

# %%
df[df['name'] == 'tc']['point_set'].unique()
# Out:
# array(['pointset1_vert', 'pointset2_fins'], dtype=object)

# %% [markdown]
# ## Pointset stats

# %%
total_samples = 74*3

for p in landmarks_pointset_names:
    total = len(df[df['point_set'] == p]['sample'])
    uniq = len(df[df['point_set'] == p]['sample'].unique())
    print(f"{p}: total {total}, unique {uniq}. finished: {round(total / (total_samples * 2) * 100, 1)}")
# Out:
# pointset1_vert: total 322, unique 180. finished: 72.5
# pointset2_fins: total 319, unique 181. finished: 71.8
# pointset3_digest: total 270, unique 160. finished: 60.8
# pointset4_heart: total 270, unique 160. finished: 60.8
# pointset5_eyes: total 160, unique 160. finished: 36.0
# pointset6_skull_front: total 241, unique 160. finished: 54.3
# pointset7_skull_center: total 142, unique 120. finished: 32.0
# pointset8_skull_end: total 141, unique 120. finished: 31.8
# pointset9_brain: total 168, unique 159. finished: 37.8

# %%
print(len(df[df['point_set'] == 'pointset9_brain']['sample'].unique()))
print(len(df[df['point_set'] == 'pointset9_brain']['sample']))
# Out:
# 159
# 168

# %%
print_landmarks_count_for_pointsets()
# Out:
# pointset1_vert: 6 landmarks
# pointset2_fins: 4 landmarks
# pointset3_digest: 2 landmarks
# pointset4_heart: 4 landmarks
# pointset5_eyes: 11 landmarks
# pointset6_skull_front: 8 landmarks
# pointset7_skull_center: 7 landmarks
# pointset8_skull_end: 6 landmarks
# pointset9_brain: 10 landmarks

# %%
print(names.count('brain'))
print(names.count('fins'))
# Out:
# 1
# 2

# %%
df[df['name'] == 'tc'].points_set.unique()
# Out:
# array(['pointset1_vert', 'pointset2_fins'], dtype=object)

# %%
df['name'].unique()
# Out:
# array(['jo', 'jvm', 'kk', 'tt', 'cs', 'tc', 'bew', 'vc', 'ra', 'ttt',
#        'fins', 'kp', 'jf', 'brain'], dtype=object)

# %%
read_landmarks(data_path / '1064_pointset1_vert_JO.mps')
# Out:
# [array([410.68527946, 361.34097292, 837.83204157]),
#  array([426.68527946, 318.24754659, 907.56993833]),
#  array([424.81810551, 311.09290667, 963.36025574]),
#  array([ 421.68527946,  308.14398353, 1020.22346386]),
#  array([ 418.13282604,  311.98799983, 1076.01378127]),
#  array([ 409.99999999,  318.95207945, 1136.04074874])]

# %%
read_landmarks(data_path / '1064_pointset1_vert_JO (1).mps')
# Out:
# [array([284.99999999, 262.78677778, 578.70023437]),
#  array([291.18236118, 238.71703727, 618.7555187 ]),
#  array([295.99999999, 227.14703661, 656.28763551]),
#  array([300.99999999, 223.67768127, 692.55816857]),
#  array([306.99999999, 221.15451376, 729.14409756]),
#  array([311.99999999, 220.83911782, 766.04542249]),
#  array([ 195.00365284,  366.0317758 , 1767.        ])]

# %%
filecmp.cmp(data_path / '1100_PointSet6_Skull_Front_RA.mps', data_path / '1100_PointSet6_Skull_Front_RA (1).mps')
# Out:
# True

# %%
[f for f in os.listdir(data_path) if os.path.isfile(f)]
# Out:
# []

# %%
len([x for x in data_path.iterdir() if x.is_file()])
# Out:
# 1816
