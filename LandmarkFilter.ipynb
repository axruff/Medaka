# %%
from pathlib import Path
from xml.dom import minidom
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

import SimpleITK as sitk

from tqdm import tqdm

import os
import shutil
import filecmp

from bs4 import BeautifulSoup

from landmarks_info import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
all_landmarks = [set_vert, set_fins, set_digest, set_heart, set_eyes, set_skull_front, set_skull_center, set_skull_end, set_brain]

landmarks_pointset_names = [x['file_name'] for x in all_landmarks]

print(landmarks_pointset_names)
# Out:
# ['pointset1_vert', 'pointset2_fins', 'pointset3_digest', 'pointset4_heart', 'pointset5_eyes', 'pointset6_skull_front', 'pointset7_skull_center', 'pointset8_skull_end', 'pointset9_brain']

# %%
eval_path = Path('c:\\Users\\fe0968\\Documents\\Medaka\\evaluation\\')

df_v7 = pd.read_excel(eval_path / 'v7' / 'eval_pointset9_brain.xlsx')
df_v8 = pd.read_excel(eval_path / 'v8' / 'eval_pointset9_brain_v8.xlsx')

# %%
df_v7
# Out:
#      Unnamed: 0  sample        point_set             landmark name1 name2  \
# 0             0    1248  pointset9_brain           hypophysis    cs    rs
# 1             1    1248  pointset9_brain     olfactoryN_right    cs    rs
# 2             2    1248  pointset9_brain      olfactoryN_left    cs    rs
# 3             3    1248  pointset9_brain       glomerulosus_R    cs    rs
# 4             4    1248  pointset9_brain       glomerulosus_L    cs    rs
# ..          ...     ...              ...                  ...   ...   ...
# 675         675    1226  pointset9_brain         OT_rightmost    cs    rs
# 676         676    1226  pointset9_brain          OT_leftmost    cs    rs
# 677         677    1226  pointset9_brain           cerebellum    cs    rs
# 678         678    1226  pointset9_brain  OT cerebellum torus    cs    rs
# 679         679    1226  pointset9_brain            epiphysis    cs    rs
#
#         result
# 0     5.919598
# 1     0.000000
# 2     0.000000
# 3     2.518606
# 4     0.864444
# ..         ...
# 675  15.707891
# 676   9.173041
# 677  12.299239
# 678   5.187814
# 679   0.372363
#
# [680 rows x 7 columns]

# %%
df_v8
# Out:
#       Unnamed: 0  sample        point_set             landmark name1 name2  \
# 0              0     526  pointset9_brain           hypophysis    ca    pw
# 1              1     526  pointset9_brain     olfactoryN_right    ca    pw
# 2              2     526  pointset9_brain      olfactoryN_left    ca    pw
# 3              3     526  pointset9_brain       glomerulosus_R    ca    pw
# 4              4     526  pointset9_brain       glomerulosus_L    ca    pw
# ...          ...     ...              ...                  ...   ...   ...
# 2185        2185     511  pointset9_brain         OT_rightmost    ca    pw
# 2186        2186     511  pointset9_brain          OT_leftmost    ca    pw
# 2187        2187     511  pointset9_brain           cerebellum    ca    pw
# 2188        2188     511  pointset9_brain  OT cerebellum torus    ca    pw
# 2189        2189     511  pointset9_brain            epiphysis    ca    pw
#
#         result
# 0     6.250938
# 1     1.733112
# 2     5.500942
# 3     1.619890
# 4     4.154976
# ...        ...
# 2185  4.431650
# 2186  8.027395
# 2187  1.163543
# 2188  3.277326
# 2189  4.180443
#
# [2190 rows x 7 columns]

# %% [markdown]
# ## Make a difference between two versions of results (old and new)

# %%
df_v7 = df_v7.drop(['Unnamed: 0'], axis=1)
df_v8 = df_v8.drop(['Unnamed: 0'], axis=1)

# %%
df = pd.concat([df_v7,df_v8]).drop_duplicates(keep=False)
df
# Out:
#       sample        point_set             landmark name1 name2    result
# 0        526  pointset9_brain           hypophysis    ca    pw  6.250938
# 1        526  pointset9_brain     olfactoryN_right    ca    pw  1.733112
# 2        526  pointset9_brain      olfactoryN_left    ca    pw  5.500942
# 3        526  pointset9_brain       glomerulosus_R    ca    pw  1.619890
# 4        526  pointset9_brain       glomerulosus_L    ca    pw  4.154976
# ...      ...              ...                  ...   ...   ...       ...
# 2185     511  pointset9_brain         OT_rightmost    ca    pw  4.431650
# 2186     511  pointset9_brain          OT_leftmost    ca    pw  8.027395
# 2187     511  pointset9_brain           cerebellum    ca    pw  1.163543
# 2188     511  pointset9_brain  OT cerebellum torus    ca    pw  3.277326
# 2189     511  pointset9_brain            epiphysis    ca    pw  4.180443
#
# [1510 rows x 6 columns]

# %% [markdown]
# ## Process all

# %%
for i in range(len(all_landmarks)):
    
    
    n = all_landmarks[i]['file_name']
    print('Processing:', n)
    
    df_old = pd.read_excel(eval_path / 'v7' / f'eval_{n}.xlsx')
    df_new = pd.read_excel(eval_path / 'v8' / f'eval_{n}_v8.xlsx')
    
    df_old = df_old.drop(['Unnamed: 0'], axis=1)
    df_new = df_new.drop(['Unnamed: 0'], axis=1)
    
    df_diff = pd.concat([df_old,df_new]).drop_duplicates(keep=False)
    
    df_diff.to_excel(eval_path / 'diff_v7_v8' / f'eval_{n}_diff_v7_v8.xlsx')
# Out:
# Processing: pointset1_vert  NEW: 72
# Processing: pointset2_fins  NEW: 164
# Processing: pointset3_digest  NEW: 220
# Processing: pointset4_heart  NEW: 440
# Processing: pointset5_eyes  NEW: 0
# Processing: pointset6_skull_front  NEW: 240
# Processing: pointset7_skull_center  NEW: 246
# Processing: pointset8_skull_end  NEW: 240
# Processing: pointset9_brain  NEW: 1510

# %% [markdown]
# ## Read manual correction to make Filtered landmarks

# %%
from openpyxl import load_workbook

# %%
def get_landmark(df, sample, user, landmark_name):
    res = df[(df['sample'] == sample) & (df['name'] == user) & (df['landmark'] == landmark_name)]
    if (len(res) > 1):
        print('Error: duplicates')
        print(res)
  
    if (len(res) == 0):
        print('Error: No such data in the results')
        print(sample)
        print(user)
        print(landmark_name)
        
    #x = round(res.iloc[0]['x'],2)
    #y = round(res.iloc[0]['y'],2)
    #z = round(res.iloc[0]['z'],2)
    
    x = res.iloc[0]['x']
    y = res.iloc[0]['y']
    z = res.iloc[0]['z']
        
    return x,y,z

# %%
evaluation_path = Path('c:\\Users\\fe0968\\Documents\\data\\medaka\\landmarks\\evaluation_vis\\')
results_path = Path('c:\\Users\\fe0968\\Documents\\Medaka\\')

folder_v7 = 'by_landmark_centered'
folder_diff_v7_v8 = 'by_landmark_centered_diff_v7_v8'

# %%
res_df = pd.read_excel(results_path / 'results_landmarks_v8.xlsx')

# %%
res_df = res_df.drop(['Unnamed: 0'], axis=1)
res_df.dtypes
# Out:
# sample         int64
# point_set     object
# landmark      object
# name          object
# x            float64
# y            float64
# z            float64
# dtype: object

# %%
res_df
# Out:
#        sample        point_set                   landmark name           x  \
# 0         526   pointset1_vert  Transition skull to spine   kp  293.000000
# 1         526   pointset1_vert                      Vert1   kp  289.983033
# 2         526   pointset1_vert                      Vert2   kp  293.638389
# 3         526   pointset1_vert                      Vert3   kp  294.000000
# 4         526   pointset1_vert                      Vert4   kp  296.621422
# ...       ...              ...                        ...  ...         ...
# 23355     511  pointset9_brain               OT_rightmost   pw  173.000003
# 23356     511  pointset9_brain                OT_leftmost   pw  364.000005
# 23357     511  pointset9_brain                 cerebellum   pw  274.262913
# 23358     511  pointset9_brain        OT cerebellum torus   pw  267.927534
# 23359     511  pointset9_brain                  epiphysis   pw  268.170794
#
#                 y            z
# 0      282.826248   955.343394
# 1      251.199781   986.170074
# 2      233.759151  1013.763606
# 3      226.785634  1050.797902
# 4      223.064777  1095.812249
# ...           ...          ...
# 23355  236.560874   654.491076
# 23356  236.560874   650.138201
# 23357  191.952753   706.000000
# 23358  203.061912   657.787682
# 23359  235.672668   570.000000
#
# [23360 rows x 7 columns]

# %%
res_df = res_df.drop_duplicates()
print('After dropping duplicates:',len(res_df))
# Out:
# After dropping duplicates: 23341

# %%
sample_list = []
pointset_list = []
landmark_list = []
x_list = []
y_list = []
z_list = []
var_list = []

# %%
def process_evaluation_files(folder, file_postfix):

    for pointset in all_landmarks:

        pointset_name = pointset['name'] 

        #print(pointset['file_name'])

        for land in pointset['landmarks']:

            i = str(pointset['landmarks'].index(land)).zfill(2)

            file_name = f'{i}_{land}{file_postfix}.xlsx' 
            #print(file_name)

            path = evaluation_path / folder / pointset['file_name'] / file_name

            if not Path.exists(path):
                continue

            # Open Excel stats file
            wb = load_workbook(path)
            ws = wb.active

            # Select name fields
            if ws['F1'].value == 'name1' and ws['G1'].value == 'name2':
                name1_selector = 'F'
                name2_selector = 'G'
                sample_selector = 'C'
            elif ws['D1'].value == 'name1' and ws['E1'].value == 'name2':
                name1_selector = 'D'
                name2_selector = 'E'
                sample_selector = 'A'
            else:
                print('Error with data columns')


            cells_count = len(ws[name1_selector])


            # For all cells in a column
            for i in range(1, cells_count):

                drop_user1 = False
                drop_user2 = False
                variance = -1

                if ws[f'{name1_selector}{i+1}'].font.color != None:
                    if ws[f'{name1_selector}{i+1}'].font.color.rgb == 'FFFF0000':
                        drop_user1 = True
                        #print(ws[f'{name1}{i+1}'].value)
                if ws[f'{name2_selector}{i+1}'].font.color != None:
                    if ws[f'{name2_selector}{i+1}'].font.color.rgb == 'FFFF0000':
                        drop_user2 = True

                name1 = ws[f'{name1_selector}{i+1}'].value
                name2 = ws[f'{name2_selector}{i+1}'].value
                sample = ws[f'{sample_selector}{i+1}'].value
                
                # Drop both
                if drop_user1 and drop_user2:
                    continue                

                if not drop_user1 and drop_user2:     
                    x,y,z = get_landmark(res_df, sample, name1, land)
                    variance = -1
                    #print('Drop', name2)

                if drop_user1 and not drop_user2:     
                    x,y,z = get_landmark(res_df, sample, name2, land)
                    variance = -1
                    #print('Drop', name1)

                # Average both landmarks
                if not drop_user1 and not drop_user2:     
                    x1,y1,z1 = get_landmark(res_df, sample, name1, land)
                    x2,y2,z2 = get_landmark(res_df, sample, name2, land)

                    x = (x1 + x2) / 2.0
                    y = (y1 + y2) / 2.0
                    z = (z1 + z2) / 2.0

                    variance = round(get_distance([x1,y1,z1], [x2,y2,z2]), 2)
                    #print(variance)

                sample_list.append(sample)
                pointset_list.append(pointset_name)
                landmark_list.append(land)
                x_list.append(round(x,2))
                y_list.append(round(y,2))
                z_list.append(round(z,2))
                var_list.append(round(variance,2))

# %%
process_evaluation_files(folder_v7, '')
process_evaluation_files(folder_diff_v7_v8, '_diff_v7_v8')
print('Finished')
# Out:
# Finished

# %%
data = {
            'group': pointset_list,
            'landmark': landmark_list,
            'sample': sample_list,
            'x': x_list,      
            'y': y_list,
            'z': z_list,
            'var': var_list
           }

res_filtered_df = pd.DataFrame(data)

# %%
res_filtered_df = res_filtered_df.drop_duplicates()
res_filtered_df
# Out:
#        group                   landmark  sample       x       y        z  \
# 0       Vert  Transition skull to spine     720  271.00  265.83  1195.91
# 1       Vert  Transition skull to spine    1391  257.65  231.66   428.00
# 2       Vert  Transition skull to spine     471  350.00  324.92  1070.82
# 3       Vert  Transition skull to spine     470  356.00  318.80  1122.67
# 4       Vert  Transition skull to spine     871  313.98  326.96   546.63
# ...      ...                        ...     ...     ...     ...      ...
# 11079  Brain                  epiphysis     685  239.10  244.52   715.88
# 11080  Brain                  epiphysis    1380  254.79  190.15   200.89
# 11081  Brain                  epiphysis    1230  288.39  254.39   450.33
# 11082  Brain                  epiphysis     834  271.89  357.99   292.88
# 11083  Brain                  epiphysis    1184  286.00  240.24   441.03
#
#          var
# 0      -1.00
# 1      -1.00
# 2      -1.00
# 3      -1.00
# 4      13.40
# ...      ...
# 11079   0.48
# 11080   0.48
# 11081   0.34
# 11082   0.32
# 11083   0.14
#
# [11040 rows x 7 columns]

# %%
res_filtered_df[res_filtered_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [group, landmark, sample, x, y, z, var]
# Index: []

# %% [markdown]
# ## Make statistics

# %%
land_res = res_filtered_df[res_filtered_df['landmark'] == 'Transition skull to spine']
land_res
# Out:
#      group                   landmark  sample       x       y        z    var
# 0     Vert  Transition skull to spine     720  271.00  265.83  1195.91  -1.00
# 1     Vert  Transition skull to spine    1391  257.65  231.66   428.00  -1.00
# 2     Vert  Transition skull to spine     471  350.00  324.92  1070.82  -1.00
# 3     Vert  Transition skull to spine     470  356.00  318.80  1122.67  -1.00
# 4     Vert  Transition skull to spine     871  313.98  326.96   546.63  13.40
# ...    ...                        ...     ...     ...     ...      ...    ...
# 7987  Vert  Transition skull to spine     974  223.17  224.06   427.43   4.52
# 7988  Vert  Transition skull to spine     966  254.00  214.33   717.06   3.85
# 7989  Vert  Transition skull to spine    1197  312.50  275.31  1141.23   3.06
# 7990  Vert  Transition skull to spine    1412  315.74  307.93   530.01   2.67
# 7991  Vert  Transition skull to spine    1185  318.50  291.66  1096.76   1.63
#
# [210 rows x 7 columns]

# %%
land_res_pairs = land_res[land_res['var'] > 0]
land_res_pairs
# Out:
#      group                   landmark  sample       x       y        z    var
# 4     Vert  Transition skull to spine     871  313.98  326.96   546.63  13.40
# 5     Vert  Transition skull to spine     531  248.41  238.69   902.83  12.94
# 6     Vert  Transition skull to spine    1274  341.52  333.64   715.62  12.92
# 7     Vert  Transition skull to spine    1423  303.26  281.95   456.40  12.71
# 8     Vert  Transition skull to spine    1393  338.18  317.27   549.76  12.03
# ...    ...                        ...     ...     ...     ...      ...    ...
# 7987  Vert  Transition skull to spine     974  223.17  224.06   427.43   4.52
# 7988  Vert  Transition skull to spine     966  254.00  214.33   717.06   3.85
# 7989  Vert  Transition skull to spine    1197  312.50  275.31  1141.23   3.06
# 7990  Vert  Transition skull to spine    1412  315.74  307.93   530.01   2.67
# 7991  Vert  Transition skull to spine    1185  318.50  291.66  1096.76   1.63
#
# [205 rows x 7 columns]

# %%
pointset_list = []
land_list = []
count_list = []
mean_list = []
std_list = []
max_list = []

for pointset in all_landmarks:

        pointset_name = pointset['name'] 
        #print('-----------------------')
        #print(pointset_name)
        #print('-----------------------')

        #print(pointset['file_name'])

        for land in pointset['landmarks']:
            
            land_res = res_filtered_df[res_filtered_df['landmark'] == land]
            stat_count = len(land_res)
            
            land_res_pairs = land_res[land_res['var'] > 0] 
            m = land_res_pairs.loc[:, 'var'].mean()
            s = land_res_pairs.loc[:, 'var'].std()
            mx = land_res_pairs.loc[:, 'var'].max()
            
            pointset_list.append(pointset_name)
            land_list.append(land)
            count_list.append(stat_count)
            mean_list.append(m)
            std_list.append(s)
            max_list.append(mx)
            
            
            #print(f'{land}. count: {stat_count}, mean: {round(m,1)}, std: {round(s,1)}')
            
data = {
            'group': pointset_list,
            'landmark': land_list,
            'count': count_list,
            'mean': mean_list,      
            'std': std_list,
            'max': max_list
           }

stat_df = pd.DataFrame(data).sort_values('mean', ascending=False)
stat_df
# Out:
#            group                                           landmark  count  \
# 10          Fins                         Abdominal_fins back 2_left    217
# 8           Fins  Pectoral_dorsal most breast fin to body connec...    215
# 7           Fins  Pectoral_dorsal most breast fin to body connec...    215
# 9           Fins                        Abdominal_fins back 1_right    217
# 14         Heart                                      sinus venosus    215
# 42     Skull End                    fusion of epibranchial artery 2    213
# 12        Digest                                          esophagus    211
# 51         Brain                                        OT_leftmost    218
# 32   Skull Front                                  upper jaw channel    191
# 50         Brain                                       OT_rightmost    219
# 15         Heart                                  apex of ventricle    199
# 18          Eyes                            optic nerve head 2_left    177
# 53         Brain                                OT cerebellum torus    218
# 17          Eyes                           optic nerve head 1_right    177
# 22          Eyes                               most_posterior_right    175
# 35  Skull Center                     hyoid between branchial arches    204
# 11        Digest                                        anus_Center    209
# 34  Skull Center                                 subhypophysis bone    207
# 23          Eyes                                most_posterior_left    176
# 52         Brain                                         cerebellum    219
# 27          Eyes                                  most_ventral_left    178
# 40     Skull End                             skull landmark A right    215
# 24          Eyes                                  most_dorsal_right    178
# 26          Eyes                                 most_ventral_right    178
# 41     Skull End                              skull landmark A left    217
# 30   Skull Front                                   mandible dentary    169
# 25          Eyes                                   most_dorsal_left    178
# 0           Vert                          Transition skull to spine    210
# 13         Heart             tip of bulbus arteriosus vessel inside    216
# 5           Vert                                              Vert5    210
# 20          Eyes                                most_anterior_right    175
# 4           Vert                                              Vert4    210
# 19          Eyes                              optic chiasm_crossing    178
# 21          Eyes                                 most_anterior_left    175
# 45         Brain                                         hypophysis    219
# 31   Skull Front                                         tongue tip    186
# 47         Brain                                    olfactoryN_left    215
# 43     Skull End                            center of utricle right    215
# 46         Brain                                   olfactoryN_right    214
# 16         Heart                   anterior most point of ventricle    217
# 44     Skull End                             center of utricle left    219
# 37  Skull Center               split of afferent branchial artery 2    216
# 36  Skull Center               split of afferent branchial artery 1    217
# 48         Brain                                     glomerulosus_R    219
# 33   Skull Front                                       hyoid fusion    216
# 39  Skull Center                                    gills bone left    217
# 49         Brain                                     glomerulosus_L    219
# 29   Skull Front                 dorsal side of nostril outlet left    207
# 54         Brain                                          epiphysis    219
# 28   Skull Front                dorsal side of nostril outlet right    209
# 38  Skull Center                                   gills bone right    218
# 3           Vert                                              Vert3    205
# 2           Vert                                              Vert2    206
# 1           Vert                                              Vert1    208
# 6           Vert                                   Vert_Last_Center      0
#
#          mean         std      max
# 10  28.523056  126.951059  1508.65
# 8   23.455146   63.747886   915.81
# 7   18.456893   13.704464    83.48
# 9   16.205880    8.399423    70.47
# 14   9.573382    6.417308    35.66
# 42   9.062250   76.261524  1081.15
# 12   8.256219    5.371706    28.48
# 51   7.956667    5.660804    30.40
# 32   7.916768    6.525835    28.25
# 50   7.246714    5.457124    28.41
# 15   7.160161    6.707687    37.31
# 18   5.921705    3.267591    12.99
# 53   5.830376    3.152346    16.11
# 17   5.798864    3.059416    12.45
# 22   5.680353    6.318495    41.19
# 35   5.581543    3.309681    20.59
# 11   5.556200    4.766685    22.00
# 34   5.460743    3.749495    22.00
# 23   5.275439    6.358709    46.04
# 52   5.209206    3.677724    25.16
# 27   5.180966    6.926832    42.77
# 40   5.134560    3.294832    13.91
# 24   5.071207    6.761954    42.51
# 26   4.977386    5.749879    37.31
# 41   4.841406    3.131324    16.38
# 30   4.756753    3.325046    17.98
# 25   4.697931    5.937940    43.97
# 0    4.668146    2.751025    13.40
# 13   4.625860    2.949498    17.32
# 5    4.408810   12.540556   124.27
# 20   4.359943    6.567101    47.18
# 4    4.313762   12.268149   118.47
# 19   4.302599    2.779829    23.01
# 21   4.202832    6.667371    42.87
# 45   3.936129    3.034594    20.62
# 31   3.932265    2.848957    14.67
# 47   3.578308    3.108523    15.14
# 43   3.475962    2.432160    11.35
# 46   3.370881    2.857507    14.38
# 16   3.298333    3.467816    23.09
# 44   3.077837    2.257452    13.63
# 37   2.917857    1.466546    12.23
# 36   2.778667    1.643291    11.12
# 48   2.585926    1.403922     7.27
# 33   2.458793    1.788879    12.51
# 39   2.422850    2.321764    10.54
# 49   2.414074    1.390217     8.69
# 29   2.174830    1.622724    12.81
# 54   1.984101    1.308966     9.07
# 28   1.931833    1.151332     6.75
# 38   1.898693    1.628221    13.44
# 3    1.814826    1.411561    10.04
# 2    1.798966    1.510644    16.26
# 1    1.689657    1.097544     8.69
# 6         NaN         NaN      NaN

# %%
res_filtered_df[res_filtered_df.duplicated()]
# Out:
#              group                                landmark  sample       x  \
# 8193          Vert               Transition skull to spine    1300  327.09
# 8194          Vert               Transition skull to spine    1300  327.09
# 8207          Vert                                   Vert1    1300  330.79
# 8208          Vert                                   Vert1    1300  330.79
# 8219          Vert                                   Vert2    1300  332.32
# 8220          Vert                                   Vert2    1300  332.32
# 8233          Vert                                   Vert3    1300  333.83
# 8234          Vert                                   Vert3    1300  333.83
# 8242          Vert                                   Vert4    1300  331.55
# 8243          Vert                                   Vert4    1300  331.55
# 8256          Vert                                   Vert5    1300  331.50
# 8257          Vert                                   Vert5    1300  331.50
# 8430        Digest                             anus_Center    1300  288.49
# 8431        Digest                             anus_Center    1300  288.49
# 8504        Digest                             anus_Center    1296  390.04
# 8548        Digest                               esophagus    1300  325.74
# 8588        Digest                               esophagus    1296  358.54
# 8704         Heart  tip of bulbus arteriosus vessel inside    1300  325.98
# 8705         Heart  tip of bulbus arteriosus vessel inside    1300  325.98
# 8824         Heart                           sinus venosus    1300  326.76
# 8825         Heart                           sinus venosus    1300  326.76
# 8867         Heart                       apex of ventricle    1300  356.00
# 8868         Heart                       apex of ventricle    1300  356.00
# 9063         Heart        anterior most point of ventricle    1300  328.50
# 9064         Heart        anterior most point of ventricle    1300  328.50
# 9350  Skull Center                      subhypophysis bone     804  419.04
# 9393  Skull Center          hyoid between branchial arches     804  425.21
# 9449  Skull Center    split of afferent branchial artery 1     804  422.19
# 9488  Skull Center    split of afferent branchial artery 2     804  418.61
# 9499  Skull Center                        gills bone right     804  384.87
# 9559  Skull Center                         gills bone left     804  433.39
# 9615     Skull End                  skull landmark A right     979  324.83
# 9616     Skull End                  skull landmark A right     979  324.83
# 9620     Skull End                  skull landmark A right    1075  315.60
# 9657     Skull End                   skull landmark A left    1075  407.85
# 9665     Skull End                   skull landmark A left     979  426.61
# 9666     Skull End                   skull landmark A left     979  426.61
# 9682     Skull End         fusion of epibranchial artery 2     979  377.39
# 9683     Skull End         fusion of epibranchial artery 2     979  377.39
# 9695     Skull End         fusion of epibranchial artery 2    1075  369.72
# 9728     Skull End                 center of utricle right     979  276.69
# 9729     Skull End                 center of utricle right     979  276.69
# 9764     Skull End                 center of utricle right    1075  281.77
# 9779     Skull End                  center of utricle left     979  480.11
# 9780     Skull End                  center of utricle left     979  480.11
# 9806     Skull End                  center of utricle left    1075  466.31
#
#            y        z    var
# 8193  313.02   756.40   5.95
# 8194  313.02   756.40   5.95
# 8207  275.04   805.47   1.04
# 8208  275.04   805.47   1.04
# 8219  261.77   845.94   2.15
# 8220  261.77   845.94   2.15
# 8233  257.16   887.39   1.09
# 8234  257.16   887.39   1.09
# 8242  251.90   936.97   2.08
# 8243  251.90   936.97   2.08
# 8256  247.42   986.15   2.17
# 8257  247.42   986.15   2.17
# 8430  589.05  1383.75  22.00
# 8431  589.05  1383.75  22.00
# 8504  568.32  1261.50   2.12
# 8548  368.96   808.00  -1.00
# 8588  397.30   547.00   8.28
# 8704  518.67   698.23   4.71
# 8705  518.67   698.23   4.71
# 8824  475.29   793.26   8.66
# 8825  475.29   793.26   8.66
# 8867  579.71   783.54  -1.00
# 8868  579.71   783.54  -1.00
# 9063  544.96   688.77   1.03
# 9064  544.96   688.77   1.03
# 9350  374.70   587.70   7.40
# 9393  451.12   500.07   5.79
# 9449  468.27   530.39   1.04
# 9488  471.69   574.67   1.51
# 9499  391.24   673.00   4.62
# 9559  388.12   674.50   1.19
# 9615  340.50   632.84   5.07
# 9616  340.50   632.84   5.07
# 9620  317.50   927.60   2.66
# 9657  320.13   928.57   7.55
# 9665  340.50   631.59   3.18
# 9666  340.50   631.59   3.18
# 9682  419.31   617.27   6.65
# 9683  419.31   617.27   6.65
# 9695  372.69   879.00   3.43
# 9728  409.50   487.54   8.04
# 9729  409.50   487.54   8.04
# 9764  334.76   784.36   0.82
# 9779  405.00   489.91   5.15
# 9780  405.00   489.91   5.15
# 9806  340.47   793.97   1.26

# %%
wb = load_workbook('03_tongue tip.xlsx')
ws = wb.active

# Select name fields
if ws['F1'].value == 'name1' and ws['G1'].value == 'name2':
    name1_selector = 'F'
    name2_selector = 'G'
    sample_selector = 'C'
elif ws['D1'].value == 'name1' and ws['E1'].value == 'name2':
    name1_selector = 'D'
    name2_selector = 'E'
    sample_selector = 'A'
else:
    print('Error with data columns')
    
print(sample_selector, name1_selector, name2_selector)
# Out:
# A D E

# %%
cells_count = len(ws[name1_selector])


# For all cells in a column
for i in range(1, cells_count):
    
    drop_user1 = False
    drop_user2 = False
    variance = -1
    
    if ws[f'{name1_selector}{i+1}'].font.color != None:
        if ws[f'{name1_selector}{i+1}'].font.color.rgb == 'FFFF0000':
            drop_user1 = True
            #print(ws[f'{name1}{i+1}'].value)
    if ws[f'{name2_selector}{i+1}'].font.color != None:
        if ws[f'{name2_selector}{i+1}'].font.color.rgb == 'FFFF0000':
            drop_user2 = True
            
    name1 = ws[f'{name1_selector}{i+1}'].value
    name2 = ws[f'{name2_selector}{i+1}'].value
    sample = ws[f'{sample_selector}{i+1}'].value
            
    if not drop_user1 and drop_user2:     
        x,y,z = get_landmark(res_df, sample, name1, 'tongue tip')
        variance = -1
        #print('Drop', name2)
        
    if drop_user1 and not drop_user2:     
        x,y,z = get_landmark(res_df, sample, name2, 'tongue tip')
        variance = -1
        #print('Drop', name1)
        
    if not drop_user1 and not drop_user2:     
        x1,y1,z1 = get_landmark(res_df, sample, name1, 'tongue tip')
        x2,y2,z2 = get_landmark(res_df, sample, name2, 'tongue tip')
        
        x = (x1 + x2) / 2.0
        y = (y1 + y2) / 2.0
        z = (z1 + z2) / 2.0
        
        variance = round(get_distance([x1,y1,z1], [x2,y2,z2]), 2)
        #print(variance)

# %%
# Out:
# Empty DataFrame
# Columns: [sample, point_set, landmark, name, x, y, z]
# Index: []

# %%
pointset = all_landmarks[4]
print(pointset)
# Out:
# {'name': 'Eyes', 'file_name': 'pointset5_eyes', 'landmarks': ['optic nerve head 1_right', 'optic nerve head 2_left', 'optic chiasm_crossing', 'most_anterior_right', 'most_anterior_left', 'most_posterior_right', 'most_posterior_left', 'most_dorsal_right', 'most_dorsal_left', 'most_ventral_right', 'most_ventral_left']}

# %%
data = {'sample': sample_list,
           'point_set': pointset_list,
            'landmark': landmark_list,
            'name': user_list,
            'x': x_list,      
            'y': y_list,
            'z': z_list,
           }

    res_df = pd.DataFrame(data)
    
    if save:
        res_df.to_excel(file_name)
