# %%
from pathlib import Path
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pytiff

import SimpleITK as sitk
import os

import multiprocessing as mp

# %%
#path_data = Path("c:\\Users\\fe0968\\Documents\\Medaka\\_alignment_info_new\\")
path_data =Path("z:\\tomo\\ershov\\medaka\\workshop_landmarks\\data")
path_masks = Path("z:\\tomo\\ershov\\medaka\\workshop_landmarks\\data_masks")
path_preview = Path("z:\\tomo\\ershov\\medaka\\workshop_landmarks\\data_masks")


path_data = Path("/mnt/LSDF/tomo/ershov/medaka/workshop_landmarks/data")
path_masks = Path("/mnt/LSDF/tomo/ershov/medaka/workshop_landmarks/data_masks")
path_preview = Path("/mnt/LSDF/tomo/ershov/medaka/workshop_landmarks/data_masks_preview")

# %%
sample = '1064'

sitk_image = sitk.ReadImage(path_data / f'{sample}.tif')
im = sitk.GetArrayViewFromImage(sitk_image)

sitk_mask= sitk.ReadImage(path_masks / f'{sample}.tif')
mask= sitk.GetArrayViewFromImage(sitk_mask)

#del sitk_image

# %%
plt.imshow(part)

# %%
def make_mask_figure(im, mask, file_name):
    
    d = im.shape[0]
    w = im.shape[2]
    h = im.shape[1]

    fig = plt.figure(figsize= (14,9), layout="tight")

    gs = GridSpec(2, 1, figure=fig)
    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[1, 0])


    ax1.imshow(im[:,:,int(w/2)].T, cmap='gray')
    ax1.imshow(mask[:,:,int(w/2)].T, alpha=0.5)

    ax2.imshow(im[:,int(h/2),:].T, cmap='gray')
    ax2.imshow(mask[:,int(h/2),:].T, alpha=0.5)

    for i, ax in enumerate(fig.axes):
            ax.set_xticks([])
            ax.set_yticks([])  
            
    fig.suptitle(f"{sample}")
    
    plt.savefig(f'res_centered_eval.png')

# %%
make_mask_figure(im,mask, sample)

# %%
files = os.listdir('z:\\tomo\\ershov\\medaka\\workshop_landmarks\\data_masks\\')

datasets = [f.split('.')[0] for f in files]

# %%
datasets
# Out:
# ['1064',
#  '1071',
#  '1075',
#  '1076',
#  '1081',
#  '1082',
#  '1086',
#  '1100',
#  '1104',
#  '1105',
#  '1106',
#  '1119',
#  '1126',
#  '1129',
#  '1131',
#  '1134',
#  '1149',
#  '1155',
#  '1157',
#  '1170',
#  '1181',
#  '1184',
#  '1185',
#  '1191',
#  '1192',
#  '1197',
#  '1216',
#  '1217',
#  '1219',
#  '1222',
#  '1226',
#  '1227',
#  '1230',
#  '1232',
#  '1234',
#  '1248',
#  '1256',
#  '1257',
#  '1258',
#  '1264',
#  '1265',
#  '1269',
#  '1273',
#  '1274',
#  '1282',
#  '1284',
#  '1285',
#  '1291',
#  '1292',
#  '1293',
#  '1295',
#  '1296',
#  '1297',
#  '1300',
#  '1305',
#  '1310',
#  '1320',
#  '1321',
#  '1323',
#  '1337',
#  '1338',
#  '1341',
#  '1346',
#  '1351',
#  '1353',
#  '1362',
#  '1363',
#  '1366',
#  '1369',
#  '1370',
#  '1372',
#  '1376',
#  '1378',
#  '1380',
#  '1383',
#  '1384',
#  '1385',
#  '1389',
#  '1391',
#  '1393',
#  '1394',
#  '1395',
#  '1396',
#  '1399',
#  '1400',
#  '1401',
#  '1404',
#  '1405',
#  '1406',
#  '1412',
#  '1413',
#  '1414',
#  '1417',
#  '1418',
#  '1423',
#  '417',
#  '418',
#  '421',
#  '423',
#  '425',
#  '428',
#  '444',
#  '446',
#  '448',
#  '454',
#  '459',
#  '463',
#  '470',
#  '471',
#  '475',
#  '488',
#  '489',
#  '493',
#  '500',
#  '501',
#  '502',
#  '508',
#  '509',
#  '511',
#  '526',
#  '528',
#  '531',
#  '535',
#  '537',
#  '547',
#  '555',
#  '561',
#  '565',
#  '578',
#  '582',
#  '586',
#  '601',
#  '603',
#  '605',
#  '606',
#  '608',
#  '610',
#  '613',
#  '614',
#  '619',
#  '622',
#  '626',
#  '629',
#  '639',
#  '640',
#  '641',
#  '649',
#  '652',
#  '660',
#  '679',
#  '684',
#  '685',
#  '692',
#  '699',
#  '702',
#  '707',
#  '709',
#  '710',
#  '720',
#  '721',
#  '724',
#  '800',
#  '801',
#  '803',
#  '804',
#  '805',
#  '807',
#  '809',
#  '811',
#  '814',
#  '816',
#  '818',
#  '819',
#  '820',
#  '824',
#  '826',
#  '828',
#  '831',
#  '834',
#  '837',
#  '838',
#  '841',
#  '843',
#  '844',
#  '846',
#  '849',
#  '853',
#  '854',
#  '856',
#  '859',
#  '860',
#  '863',
#  '865',
#  '870',
#  '871',
#  '876',
#  '879',
#  '880',
#  '883',
#  '890',
#  '891',
#  '893',
#  '906',
#  '909',
#  '912',
#  '913',
#  '914',
#  '919',
#  '946',
#  '947',
#  '951',
#  '954',
#  '955',
#  '956',
#  '960',
#  '961',
#  '966',
#  '971',
#  '972',
#  '974',
#  '978',
#  '979']
